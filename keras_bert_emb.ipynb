# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Обучение моделей с классификатором keras и эмбеддерами BERT

# %%
# !pip install tensorflow-gpu
# !pip install deeppavlov
# !python -m deeppavlov install squad_bert
# !pip install fasttext
# !pip install transformers
# !python -m deeppavlov install bert_sentence_embedder
# Out:
# ...
#      |████████████████████████████████| 454.3MB 31kB/s
# ...
#      |████████████████████████████████| 471kB 61.3MB/s
# ...
#      |████████████████████████████████| 4.0MB 38.4MB/s
# ...
#      |████████████████████████████████| 1.2MB 47.3MB/s
# ...
#      |████████████████████████████████| 6.0MB 44.9MB/s
# ...
#      |████████████████████████████████| 4.0MB 41.9MB/s
# ...
#      |████████████████████████████████| 4.9MB 63.1MB/s
# ...
# ERROR: tensorflow 2.4.1 has requirement gast==0.3.3, but you'll have gast 0.4.0 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement grpcio~=1.32.0, but you'll have grpcio 1.34.1 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement h5py~=2.10.0, but you'll have h5py 3.1.0 which is incompatible.
# ERROR: tensorflow 2.4.1 has requirement tensorflow-estimator<2.5.0,>=2.4.0, but you'll have tensorflow-estimator 2.5.0 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
# ...

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14312724982187215954
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 6979465986306983024
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 16968922782594469469
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15964005991
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3606425242727234614
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
from deeppavlov import train_model, configs
import json

# %% [markdown]
# ### Модель с эмбеддером из модели rubert

# %%
bert = train_model('/content/drive/MyDrive/BERT/configs/keras_rubert_prep_emb.json')
# Out:
# 2021-05-11 15:04:22.741 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# 2021-05-11 15:04:23.441 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# ...

# %% [markdown]
# ### Модель с эмбеддером из модели rubert_base_cased_sentiment

# %%
bert = train_model('/content/drive/MyDrive/BERT/configs/keras_rusent_prep_emb.json')
# Out:
# 2021-05-11 20:14:33.711 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 20:14:34.618 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/bert_models/classes.dict]
# 2021-05-11 20:14:48.767 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 216: [initializing `KerasClassificationModel` from scratch as cnn_model]
# 2021-05-11 20:14:49.894 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 129: Model was successfully initialized!
# Model summary:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...

# %% [markdown]
# ### Модель с эмбеддером из модели rubert_conversational_cased

# %%
bert = train_model('/content/drive/MyDrive/BERT/configs/keras_ruconv_prep_emb.json')
# Out:
# 2021-05-11 19:17:22.973 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# 2021-05-11 19:17:24.214 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/bert_models/classes.dict]
# ...

# %% [markdown]
# ### Модель с эмбеддером из модели bert_multi_cased_sentence

# %%
bert = train_model('/content/drive/MyDrive/BERT/configs/keras_multi_prep_emb.json')
# Out:
# 2021-05-18 00:52:39.884 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-18 00:52:41.536 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/sentence_multi_cased_L-12_H-768_A-12_pt/classes.dict]
# 2021-05-18 00:53:02.520 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 216: [initializing `KerasClassificationModel` from scratch as cnn_model]
# 2021-05-18 00:53:02.983 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 129: Model was successfully initialized!
# Model summary:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...

# %% [markdown]
# ### Модель с эмбеддером из модели bert_multu_cased

# %%
bert = train_model('/content/drive/MyDrive/BERT/configs/keras_multi_cased_prep_emb.json')
# Out:
# 2021-05-18 02:13:34.662 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-18 02:13:34.675 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/bert-base-multilingual-cased/classes.dict]
# 2021-05-18 02:13:35.517 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/bert-base-multilingual-cased/classes.dict]
# 2021-05-18 02:13:51.51 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 216: [initializing `KerasClassificationModel` from scratch as cnn_model]
# 2021-05-18 02:13:51.513 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 129: Model was successfully initialized!
# Model summary:
# Model: "model"
# ...

# %% [markdown]
# ### Модель с эмбеддером из модели rubert_conversational_cased

# %%
bert = train_model('/content/drive/MyDrive/BERT/configs/keras_bert/keras_ruconv_prep_emb.json')
# Out:
# 2021-05-18 23:48:20.835 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# [nltk_data]   Package perluniprops is already up-to-date!
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package nonbreaking_prefixes is already up-to-date!
# 2021-05-18 23:48:22.92 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/custom_bert/classes.dict]
# ...

# %% [markdown]
# ### Модель с эмбеддером из модели rubert_conversational_cased

# %%
# ru conversational
bert = train_model('/content/drive/MyDrive/BERT/configs/keras_bert/keras_ruconv_prep_emb.json')
# Out:
# 2021-05-19 08:03:52.72 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# [nltk_data]   Unzipping misc/perluniprops.zip.
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping corpora/nonbreaking_prefixes.zip.
# 2021-05-19 08:03:53.508 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/custom_bert/classes.dict]
# ...
