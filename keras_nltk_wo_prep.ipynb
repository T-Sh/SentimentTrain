# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Обучение моделей с классификатором keras и эмбеддером NLTK

# %%
# !pip install tensorflow-gpu
# !pip install deeppavlov
# !python -m deeppavlov install squad_bert
# !pip install fasttext
# !pip install transformers
# !python -m deeppavlov install bert_sentence_embedder
# Out:
# ...
#      |████████████████████████████████| 454.3MB 35kB/s
# ...
#      |████████████████████████████████| 911kB 2.9MB/s
# ...
#      |████████████████████████████████| 1.5MB 15.2MB/s
# ...
#      |████████████████████████████████| 61kB 8.8MB/s
# ...
#      |████████████████████████████████| 3.8MB 11.1MB/s
# ...
#      |████████████████████████████████| 10.4MB 15.7MB/s
# ...
#      |████████████████████████████████| 655kB 48.4MB/s
# ...
#      |████████████████████████████████| 860kB 48.5MB/s
# ...
#      |████████████████████████████████| 71kB 9.3MB/s
# ...
#      |████████████████████████████████| 51kB 9.0MB/s
# ...
#      |████████████████████████████████| 6.7MB 64.7MB/s
# ...
#      |████████████████████████████████| 512kB 67.3MB/s
# ...
#      |████████████████████████████████| 51kB 8.3MB/s
# ...
#      |████████████████████████████████| 20.1MB 302kB/s
# ...
#      |████████████████████████████████| 51kB 9.0MB/s
# ...
#      |████████████████████████████████| 51kB 8.1MB/s
# ...
#      |████████████████████████████████| 2.1MB 35.5MB/s
# ...

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4703519187182482179
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4624739383253632929
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 1390395788526921675
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15964005991
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1438932875083469394
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
from deeppavlov import train_model, configs
import json

# %% [markdown]
# ## Обучение на корпусе с отзывами об отелях

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_tokenize_hotel.json')
# Out:
# 2021-05-11 11:03:40.73 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# [nltk_data]   Unzipping misc/perluniprops.zip.
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping corpora/nonbreaking_prefixes.zip.
# 2021-05-11 11:03:41.827 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# ...

# %% [markdown]
# ## Обучение на корпусе с новостями

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_tokenize_kaggle.json')
# Out:
# 2021-05-11 11:14:25.305 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 11:14:25.309 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:14:25.318 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:14:25.324 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/ft_native_300_ru_wiki_lenta_nltk_wordpunct_tokenize.bin`]
# ...
# 2021-05-11 11:14:40.393 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 245: [initializing `KerasClassificationModel` from saved]
# ...

# %% [markdown]
# ## Обучение на корпусе LINIS

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_tokenize_linis.json')
# Out:
# 2021-05-11 11:22:29.87 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 11:22:29.91 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:22:29.110 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:22:29.118 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/ft_native_300_ru_wiki_lenta_nltk_wordpunct_tokenize.bin`]
# ...
# 2021-05-11 11:24:00.119 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 245: [initializing `KerasClassificationModel` from saved]
# ...

# %% [markdown]
# ## Обучение на корпусе с отзывами о ресторанах

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_tokenize_restaraunt.json')
# Out:
# 2021-05-11 11:30:56.116 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 11:30:56.121 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:30:56.143 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:30:56.151 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/ft_native_300_ru_wiki_lenta_nltk_wordpunct_tokenize.bin`]
# ...
# 2021-05-11 11:32:22.219 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 245: [initializing `KerasClassificationModel` from saved]
# ...

# %% [markdown]
# ## Обучение на корпусе с отзывами об автомобилях

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_tokenize_reviews.json')
# Out:
# 2021-05-11 11:39:36.53 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 11:39:36.60 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:39:36.69 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:39:36.76 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/ft_native_300_ru_wiki_lenta_nltk_wordpunct_tokenize.bin`]
# ...
# 2021-05-11 11:41:02.224 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 245: [initializing `KerasClassificationModel` from saved]
# ...

# %% [markdown]
# ## Обучение на корпусе с отзывами о мед. организациях

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_tokenize_spr.json')
# Out:
# 2021-05-11 11:45:12.587 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 11:45:12.593 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:45:12.906 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:45:12.915 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/ft_native_300_ru_wiki_lenta_nltk_wordpunct_tokenize.bin`]
# ...
# 2021-05-11 11:46:39.197 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 245: [initializing `KerasClassificationModel` from saved]
# ...

# %% [markdown]
# ## Обучение на корпусе с неприятными комментариями

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_tokenize_toxic.json')
# Out:
# 2021-05-11 11:58:31.735 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 11:58:31.740 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:58:31.754 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 11:58:31.761 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/ft_native_300_ru_wiki_lenta_nltk_wordpunct_tokenize.bin`]
# ...
# 2021-05-11 11:59:57.993 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 245: [initializing `KerasClassificationModel` from saved]
# ...

# %% [markdown]
# ## Обучение на общем корпусе

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_tokenize.json')
# Out:
# 2021-05-11 12:04:50.423 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 12:04:50.436 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 12:04:51.133 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 12:04:51.256 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/ft_native_300_ru_wiki_lenta_nltk_wordpunct_tokenize.bin`]
# ...
# 2021-05-11 12:06:17.532 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 245: [initializing `KerasClassificationModel` from saved]
# ...

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/keras_nltk/emb_tokenize.json')
# Out:
# 2021-05-26 11:48:28.698 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package perluniprops to /root/nltk_data...
# [nltk_data]   Unzipping misc/perluniprops.zip.
# [nltk_data] Downloading package nonbreaking_prefixes to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping corpora/nonbreaking_prefixes.zip.
# 2021-05-26 11:48:31.42 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# ...

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/keras_nltk/emb_tokenize.json')
# Out:
# 2021-05-26 12:30:57.70 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-26 12:30:57.811 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-26 12:30:57.819 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/emb.bin`]
# ...
# 2021-05-26 12:31:02.940 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 216: [initializing `KerasClassificationModel` from scratch as cnn_model]
# 2021-05-26 12:31:03.490 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 129: Model was successfully initialized!
# Model summary:
# Model: "model"
# ...

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/keras_nltk/ru_tokenize.json')
# Out:
# 2021-05-27 00:02:39.570 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-27 00:02:39.582 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-27 00:02:40.410 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-27 00:02:40.422 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/nltk/cc.ru.300.bin`]
# ...
# 2021-05-27 00:04:03.219 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 245: [initializing `KerasClassificationModel` from saved]
# ...
