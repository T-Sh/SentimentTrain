# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Обучение моделей с классификатором keras и эмбеддером NLTK и лемматизацией

# %%
# !pip install tensorflow-gpu
# !pip install deeppavlov
# !python -m deeppavlov install squad_bert
# !pip install fasttext
# !pip install transformers
# !python -m deeppavlov install bert_sentence_embedder
# Out:
# ...
# 2021-05-17 18:25:24.564 INFO in 'deeppavlov.core.common.file'['file'] at line 32: Interpreting 'squad_bert' as '/usr/local/lib/python3.7/dist-packages/deeppavlov/configs/squad/squad_bert.json'
# 2021-05-17 18:25:25.363 WARNING in 'deeppavlov.utils.pip_wrapper.pip_wrapper'['pip_wrapper'] at line 34: found tensorflow-gpu installed, so upgrading it instead of tensorflow
# ...
#   Cloning https://github.com/deepmipt/bert.git (to revision feat/multi_gpu) to /tmp/pip-req-build-w2sxzd3z
#   Running command git clone -q https://github.com/deepmipt/bert.git /tmp/pip-req-build-w2sxzd3z
# ...
#   Created wheel for bert-dp: filename=bert_dp-1.0-cp37-none-any.whl size=23581 sha256=f28fa3dcc763fd2286291da512ebebf33b27216ee1d9a8aa6f44f75d0b656b26
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u44_lz9u/wheels/1e/41/94/886107eaf932532594886fd8bfc9cb9d4db632e94add49d326
# Successfully built bert-dp
# ...

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 578263119643595805
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12066054153765024510
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8071287491018349946
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 15964005991
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11203379340906706314
# physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
# ]

# %%
from deeppavlov import train_model, configs
import json

# %% [markdown]
# ## Обучение на корпусе с отзывами о мед. организациях

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_lemmatize_spr.json')
# Out:
# 2021-05-11 03:57:30.591 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 03:57:31.525 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 03:57:31.533 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/ft_native_300_ru_wiki_lenta_lemmatize.bin`]
# ...
# 2021-05-11 03:58:36.613 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 216: [initializing `KerasClassificationModel` from scratch as cnn_model]
# 2021-05-11 03:58:37.70 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 129: Model was successfully initialized!
# Model summary:
# Model: "model"
# ...

# %% [markdown]
# ## Обучение на корпусе с неприятными комментариями

# %%
model = train_model('/content/drive/MyDrive/BERT/configs/nltk_lemmatize_toxic.json')
# Out:
# 2021-05-11 04:08:43.915 WARNING in 'deeppavlov.dataset_readers.basic_classification_reader'['basic_classification_reader'] at line 112: Cannot find /content/drive/MyDrive/BERT/train/test.csv file
# 2021-05-11 04:08:43.919 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 04:08:44.163 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 101: [saving vocabulary to /content/drive/MyDrive/BERT/models/classes.dict]
# 2021-05-11 04:08:44.174 INFO in 'deeppavlov.models.embedders.fasttext_embedder'['fasttext_embedder'] at line 53: [loading fastText embeddings from `/content/drive/MyDrive/BERT/ft_native_300_ru_wiki_lenta_lemmatize.bin`]
# ...
# 2021-05-11 04:08:52.502 INFO in 'deeppavlov.models.classifiers.keras_classification_model'['keras_classification_model'] at line 245: [initializing `KerasClassificationModel` from saved]
# ...
